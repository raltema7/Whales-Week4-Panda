# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ### Whale Returns

# %%
whale_returns_csv=(r"C:\Users\ralte\Desktop\mia-mia-fin-pt-05-2021-u-c-master-Week4_Pandas\Week4_Pandas\Week4_Pandas_HW\Starter_Code\Resources\whale_returns.csv")
whale_pd= pd.read_csv(whale_returns_csv, index_col= "Date", parse_dates= True)
df = pd.DataFrame
whale_pd.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count Nulls

whale_pd.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
# Drop nulls
whale_pd.dropna(inplace=True)
whale_pd.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ### ALGO

# %%
ALGO_csv =(r'C:\Users\ralte\Desktop\mia-mia-fin-pt-05-2021-u-c-master-Week4_Pandas\Week4_Pandas\Week4_Pandas_HW\Starter_Code\Resources\algo_returns.csv')
ALGO_rd= pd.read_csv (ALGO_csv, index_col = "Date", parse_dates = True)
ALGO_rd.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
ALGO_rd.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
ALGO_rd.dropna()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ### S&P500 Returns

# %%
sp_returns_csv=(r"C:\Users\ralte\Desktop\mia-mia-fin-pt-05-2021-u-c-master-Week4_Pandas\Week4_Pandas\Week4_Pandas_HW\Starter_Code\Resources\sp500_history.csv")
sp_pd= pd.read_csv(sp_returns_csv, index_col= "Date", parse_dates= True)
sp_pd.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types 

sp_pd.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp_pd["Close"] = sp_pd["Close"].str.replace('$', '')
sp_pd["Close"]= sp_pd["Close"].astype(float)
sp_pd.head()
# Out:
# <ipython-input-197-fe63a779d37a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sp_pd["Close"] = sp_pd["Close"].str.replace('$', '')
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Returns

sp_pd["Close"]= sp_pd["Close"].pct_change()
sp_pd.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop Nulls

sp_pd.dropna()
sp_pd
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
# Rename close in Column

sp_pd.columns= ["s&p500"]
sp_pd.head()
# Out:
#               s&p500
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %% [markdown]
# ###  Combine Whale, Algorithmic, and S&P 500 Returns

# %%
cwa_returns= pd.concat([whale_pd, ALGO_rd, sp_pd], axis="columns",join="inner")
cwa_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    s&p500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all Portfolios

cwa_returns.plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate Plot cumulative returns

# %%
# Calculate cumulative returns of all portfolios

# Plot cumulative returns

cumulative_returns = (1+cwa_returns).cumprod() -1
cumulative_returns.plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Risk Analysis

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk

cwa_returns.plot.box(figsize=(20,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

daily_std = cwa_returns.std()
print(daily_std)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# s&p500                         0.008587
# dtype: float64

# %% [markdown]
# ###  Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500

# Determine which portfolios are riskier than the S&P 500

riskier = daily_std[daily_std > daily_std["s&p500"]]
print(riskier) # Below Portfolios are Riskier because their std is GREATER than SP500
# Out:
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

annualized_std = daily_std * np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# s&p500                         0.136313
# dtype: float64

# %% [markdown]
# ###  Rolling Statistics

# %% [markdown]
# ### Calculate and plot rolling std for all portfolios with 21-day window

# %%
#  Calculate the rolling standard deviation for all portfolios using a 21-day window

cwa_returns.rolling(window=20).std().plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ###  Calculate and plot the correlation

# %%
# Calculate the correlation

import seaborn as sns
correlation = cwa_returns.corr()
sns.heatmap(correlation, vmin=-1, vmax=1,annot=True,)
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# s&p500                                        0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio

# Calculate variance of S&P 500

# Computing beta

# Plot beta trend

covariance = cwa_returns['TIGER GLOBAL MANAGEMENT LLC'].cov(cwa_returns['s&p500'])
variance = cwa_returns['s&p500'].var()
beta = covariance / variance
beta
# Out:
# -0.0019097027512373318

# %% [markdown]
# ### Rolling Statistics Challenge: Exponentially Weighted Average

# %%
rolling_covariance = cwa_returns['TIGER GLOBAL MANAGEMENT LLC'].rolling(window=60).cov(cwa_returns['s&p500'])
rolling_variance = cwa_returns['s&p500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta of TIGER GLOBAL MANAGEMENT LLC')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of TIGER GLOBAL MANAGEMENT LLC'}, xlabel='Date'>

# %%
# Use `ewm` to calculate the rolling window

cwa_returns.ewm(halflife=21).std().plot(figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Sharpe Ratios

# %%
# Annualized Sharpe ratios 


sharpe_ratios = (cwa_returns.mean() * 252) / (cwa_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# s&p500                        -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
Google_Rich = (r'C:\Users\ralte\Desktop\mia-mia-fin-pt-05-2021-u-c-master-Week4_Pandas\Week4_Pandas\Week4_Pandas_HW\Starter_Code\Resources\goog_historical.csv')
Google_Rich_df = pd.read_csv(Google_Rich, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
Google_Rich_df.rename( columns={"Symbol": "GOOG1","NOCP":"GOOG"},inplace = True )
Google_Rich_df.drop(columns=['GOOG1'], axis=1, inplace = True)

# %%
# Reading data from 2nd stock AAPL
aapl_csv = Path (r'C:\Users\ralte\Desktop\mia-mia-fin-pt-05-2021-u-c-master-Week4_Pandas\Week4_Pandas\Week4_Pandas_HW\Starter_Code\Resources\aapl_historical.csv')
aapl_df = pd.read_csv(aapl_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
aapl_df.rename( columns={"Symbol": "AAPL1","NOCP":"AAPL"},inplace = True )
aapl_df.drop(columns=['AAPL1'], axis=1, inplace= True)

# %%
cost_csv = Path(r'C:\Users\ralte\Desktop\mia-mia-fin-pt-05-2021-u-c-master-Week4_Pandas\Week4_Pandas\Week4_Pandas_HW\Starter_Code\Resources\cost_historical.csv')
cost_df = pd.read_csv(cost_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
cost_df.rename( columns={"Symbol": "COST1","NOCP":"COST"},inplace = True )
cost_df.drop(columns=['COST1'], axis=1,inplace = True)

# %%
 # Combine all stocks in a single DataFrame
combined_stock = pd.concat([Google_Rich_df,aapl_df,cost_df], axis='columns', join='inner')
combined_stock.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2019-05-09  1162.38  200.72  243.47
# 2019-05-08  1166.27  202.90  241.34
# 2019-05-07  1174.10  202.86  240.18
# 2019-05-06  1189.39  208.48  244.23
# 2019-05-03  1185.40  211.75  244.62

# %%
# Reset data index


combined_stock.sort_index(inplace=True)
combined_stock.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %%
# Calculate daily returns

# Drop NAs

# Display sample data

daily_returns = combined_stock.pct_change()
daily_returns.head()
# Out:
#                 GOOG      AAPL      COST
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14  0.001766 -0.002333  0.000613
# 2018-05-15 -0.019060 -0.009088 -0.002042
# 2018-05-16  0.002354  0.009333  0.016523
# 2018-05-17 -0.002940 -0.006324  0.004479

# %%
#drop nulls
combined_stock.dropna()
combined_stock.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %% [markdown]
# ###  Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights weights = [1/3, 1/3, 1/3]
# Calculate portfolio return
# Display sample data

weights = [1/3, 1/3, 1/3]
portfolio_returns = daily_returns.dot(weights)

custom = pd.DataFrame(portfolio_returns)
custom.head()
# Out:
#                    0
# Trade DATE
# 2018-05-11       NaN
# 2018-05-14  0.000015
# 2018-05-15 -0.010064
# 2018-05-16  0.009403
# 2018-05-17 -0.001595

# %% [markdown]
# ###  Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
 # Join your returns DataFrame to the original returns DataFrame

    
cwa_returns_stock = pd.concat([portfolio_returns, cwa_returns], axis='columns', join='inner')
cwa_returns.rename(columns= {0: "Custom"},inplace = True )
cwa_returns.dropna(inplace=True)
cwa_returns.sort_index()
cwa_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    s&p500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ###  Re-run the risk analysis with your portfolio to see how it compares to the others

# %%
# Calculate the annualized `std`

cwa_returns.std()
annualized_variance = (cwa_returns.var()*252)
annualized_std = np.sqrt(annualized_variance)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# s&p500                         0.136313
# dtype: float64

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation

cwa_returns.rolling(window=21).std().plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Calculate and plot the correlation

correlation = cwa_returns.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# s&p500                                        0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %%
sns.heatmap(correlation, vmin=-1, vmax=1,)
# Out:
# <AxesSubplot:>

# %%
# Calculate and plot Beta

rolling_variance = cwa_returns['TIGER GLOBAL MANAGEMENT LLC'].rolling(window=60).var()
rolling_covariance = cwa_returns['TIGER GLOBAL MANAGEMENT LLC'].rolling(window=60).cov(cwa_returns['s&p500'])
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 30 day beta of Tiger Global Management LLC')
# Out:
# <AxesSubplot:title={'center':'Rolling 30 day beta of Tiger Global Management LLC'}, xlabel='Date'>

# %%
# Calculate Annualzied Sharpe Ratios

sharpe_ratios_all = (cwa_returns.mean() * 252) / ((cwa_returns).std() * np.sqrt(252))
sharpe_ratios_all
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# s&p500                        -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_ratios_all.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
# Algo1 Wins!!
